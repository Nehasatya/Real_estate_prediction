# %%
import numpy as np
import pandas as pd
from xgboost import XGBRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# %%
df_train = pd.read_csv("/kaggle/input/gurgaon-real-estate-99acres-com/hyderabad.csv")

# %%
pd.set_option('display.max_columns', None)
df_train.select_dtypes('object')
# Out:
#         PROP_ID PREFERENCE                                        DESCRIPTION  \
# 0     Z70135726          S  Hmda, rera approved residential apartments at ...
# 1     A68489968          S  Own a 2 BHK apartment in Annes Fortune Greenho...
# 2     M69555358          S  This well-known project offers 4 BHK apartment...
# 3     P69555352          S  Enjoy a blissful living experience in The Olym...
# 4     B70237806          S  Siva sai infra myra is a residential developme...
# ...         ...        ...                                                ...
# 9482  X68337058          S  North and east facing approved open plots avai...
# 9483  E68336956          S  North and east facing approved open plots avai...
# 9484  R65638162          R  2bhk, independent building floor available for...
# 9485  H70874700          S  A project by sora constructions\nGhmc & rera a...
# 9486  Q70748632          S  Grama panchayithi approval\nProject located at...
#
#                   PROPERTY_TYPE          CITY                  FEATURES  \
# 0         Residential Apartment  Secunderabad        23,24,5,17,6,20,21
# 1         Residential Apartment     Hyderabad                         N
# 2         Residential Apartment     Hyderabad                         N
# 3         Residential Apartment     Hyderabad                         N
# 4       Independent House/Villa     Hyderabad                         N
# ...                         ...           ...                       ...
# 9482           Residential Land     Hyderabad                23,24,26,5
# 9483           Residential Land     Hyderabad                23,24,26,5
# 9484  Independent/Builder Floor  Secunderabad     44,23,5,39,19,9,40,21
# 9485      Residential Apartment     Hyderabad  23,24,25,5,17,19,9,40,21
# 9486      Residential Apartment     Hyderabad        23,25,5,19,9,40,21
#
#        REGISTER_DATE CLASS RES_COM                      PROP_NAME VERIFIED  \
# 0     08th Jul, 2023     A       R                         Evolve        N
# 1     12th Apr, 2023     B       R  Annes Fortune Greenhomes Swan        N
# 2     08th Jun, 2023     B       R                    The Olympus        N
# 3     08th Jun, 2023     B       R                    The Olympus        N
# 4     14th Jul, 2023     B       R            Siva Sai Infra Myra        N
# ...              ...   ...     ...                            ...      ...
# 9482  27th Jun, 2023     A       R                            NaN        N
# 9483  27th Jun, 2023     A       R                            NaN        N
# 9484  28th Jun, 2023     A       R                            NaN        N
# 9485  18th Aug, 2023     A       R             Greenwoods Project        N
# 9486  11th Aug, 2023     A       R                  Pavan Heights        N
#
#                                             MAP_DETAILS  \
# 0     {'LATITUDE': '17.575957', 'LONGITUDE': '78.471...
# 1     {'LATITUDE': '17.522103', 'LONGITUDE': '78.384...
# 2     {'LATITUDE': '17.41977', 'LONGITUDE': '78.34969'}
# 3     {'LATITUDE': '17.41977', 'LONGITUDE': '78.34969'}
# 4     {'LATITUDE': '17.513816', 'LONGITUDE': '78.244...
# ...                                                 ...
# 9482  {'LATITUDE': '17.4639176', 'LONGITUDE': '78.62...
# 9483  {'LATITUDE': '16.985875', 'LONGITUDE': '78.499...
# 9484  {'LATITUDE': '17.4653875', 'LONGITUDE': '78.47...
# 9485  {'LATITUDE': '17.47078', 'LONGITUDE': '78.30668'}
# 9486  {'LATITUDE': '17.4011618', 'LONGITUDE': '78.37...
#
#                              AMENITIES  \
# 0                   5,17,20,21,23,24,6
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 9482                        5,23,24,26
# 9483                        5,23,24,26
# 9484             5,21,44,23,39,19,9,40
# 9485  5,17,21,23,24,19,9,40,25,101,102
# 9486        5,21,23,19,9,40,25,101,102
#
#                                                 ALT_TAG     PRODUCT_TYPE  \
# 0     ₹69.25 Lac, 2 bhk Residential Apartment in Gun...  PREMIUM_LISTING
# 1                  Annes Fortune Greenhomes Swan Others   PSEUDO_LISTING
# 2                                    The Olympus Others   PSEUDO_LISTING
# 3                                    The Olympus Others   PSEUDO_LISTING
# 4                            Siva Sai Infra Myra Others   PSEUDO_LISTING
# ...                                                 ...              ...
# 9482          ₹31.73 Lac, Land/Plot in Ghatkesar - Land  PREMIUM_LISTING
# 9483               ₹33 Lac, Land/Plot in Kadthal - Land  PREMIUM_LISTING
# 9484                                                NaN  PREMIUM_LISTING
# 9485  ₹1.02 Crore, 3 bhk Residential Apartment in Na...  PREMIUM_LISTING
# 9486  ₹65 Lac, 2 bhk Residential Apartment in Maniko...  PREMIUM_LISTING
#
#                                                TOP_USPS          EXPIRY_DATE  \
# 0                                                   NaN  2023-09-06 00:00:00
# 1                                                   NaN  2023-10-09 00:00:00
# 2                                                   NaN  2023-12-05 00:00:00
# 3                                                   NaN  2023-12-05 00:00:00
# 4                                                   NaN  2024-01-10 00:00:00
# ...                                                 ...                  ...
# 9482  ['East Facing', 'Overlooking Park/Garden', 'Ov...  2023-08-26 00:00:00
# 9483  ['East Facing', 'Overlooking Park/Garden', 'Ov...  2023-08-26 00:00:00
# 9484                                                NaN  2023-08-27 00:00:00
# 9485  ['East Facing', 'The Indian Public School  Nea...  2023-10-17 00:00:00
# 9486  ['East Facing', 'Pavitra International School ...  2023-10-10 00:00:00
#
#                    AREA        SECONDARY_AREA             PRICE  \
# 0           1215 sq.ft.          112.88 sq.m.           69.25 L
# 1     1155-1395  sq.ft.    107.3-129.6  sq.m.    69.3  - 83.7 L
# 2     2880-3000  sq.ft.  267.56-278.71  sq.m.  Price on Request
# 3     2010-2020  sq.ft.  186.74-187.66  sq.m.   2.02  - 2.02 Cr
# 4     2688-3192  sq.ft.  249.72-296.55  sq.m.   2.42  - 2.87 Cr
# ...                 ...                   ...               ...
# 9482        1503 sq.ft.          139.63 sq.m.           31.73 L
# 9483        2700 sq.ft.          250.84 sq.m.              33 L
# 9484        1000 sq.ft.            92.9 sq.m.            15,000
# 9485        1600 sq.ft.          148.64 sq.m.           1.02 Cr
# 9486        1220 sq.ft.          113.34 sq.m.              65 L
#
#                                        PROP_HEADING VALUE_LABEL  \
# 0                   2 BHK Flat in Gundlapochampalli    Freehold
# 1                            2 BHK Flat in Nizampet    Freehold
# 2                        4 BHK Flat in Nanakramguda    Freehold
# 3                        3 BHK Flat in Nanakramguda    Freehold
# 4                         3 Bedroom House in Kollur    Freehold
# ...                                             ...         ...
# 9482           Residential land / Plot in Ghatkesar    Freehold
# 9483             Residential land / Plot in Kadthal    Freehold
# 9484  2 BHK Independent Builder Floor in Bowenpally         NaN
# 9485                      3 BHK Flat in Nallagandla    Freehold
# 9486                        2 BHK Flat in Manikonda    Freehold
#
#                    CLASS_HEADING CLASS_LABEL     REGISTER_DATE__U  \
# 0     Dealer: Rainbow Developers      Dealer  2023-07-08 22:01:14
# 1                        Builder     Builder  2023-04-12 11:49:40
# 2                        Builder     Builder  2023-06-08 17:30:28
# 3                        Builder     Builder  2023-06-08 17:30:27
# 4                        Builder     Builder  2023-07-14 16:16:56
# ...                          ...         ...                  ...
# 9482  Dealer: Banusai Properties      Dealer  2023-06-27 13:25:04
# 9483  Dealer: Banusai Properties      Dealer  2023-06-27 13:25:04
# 9484          Dealer: JSR Homes       Dealer  2023-06-28 00:00:00
# 9485    Dealer: Asian Properties      Dealer  2023-08-18 13:20:25
# 9486    Dealer: Asian Properties      Dealer  2023-08-11 13:39:29
#
#      REGISTERED_DAYS  PRIMARY_TAGS  \
# 0        1 month ago  ['FEATURED']
# 1       4 months ago  ['FEATURED']
# 2       2 months ago            []
# 3       2 months ago            []
# 4        1 month ago            []
# ...              ...           ...
# 9482    2 months ago            []
# 9483    2 months ago            []
# 9484     1 month ago            []
# 9485      1 week ago            []
# 9486     2 weeks ago            []
#
#                                          SECONDARY_TAGS  \
# 0                           ['READY TO MOVE', 'RESALE']
# 1         ['UNDER CONSTRUCTION', 'NEW BOOKING', 'RERA']
# 2         ['UNDER CONSTRUCTION', 'NEW BOOKING', 'RERA']
# 3         ['UNDER CONSTRUCTION', 'NEW BOOKING', 'RERA']
# 4         ['UNDER CONSTRUCTION', 'NEW BOOKING', 'RERA']
# ...                                                 ...
# 9482  ['EAST FACING', 'AUTHORITY APPROVED', 'IN GATE...
# 9483  ['EAST FACING', 'AUTHORITY APPROVED', 'IN GATE...
# 9484             ['FOR SINGLE MEN', 'FOR SINGLE WOMEN']
# 9485                   ['UNDER CONSTRUCTION', 'RESALE']
# 9486                        ['READY TO MOVE', 'RESALE']
#
#                              FORMATTED_LANDMARK_DETAILS  \
# 0                               [{'text': '1 Library'}]
# 1     [{'text': '1 Shopping'}, {'text': '3 Religious...
# 2     [{'text': '1 Metro Station'}, {'text': '1 Shop...
# 3     [{'text': '1 Metro Station'}, {'text': '1 Shop...
# 4     [{'text': '2 Connectivities'}, {'text': '1 Edu...
# ...                                                 ...
# 9482  [{'text': '2 Hospitals'}, {'text': '1 Miscella...
# 9483                                                NaN
# 9484  [{'text': '5 Religious Places'}, {'text': '8 A...
# 9485  [{'text': '8 ATMs'}, {'text': '8 Hospitals'}, ...
# 9486  [{'text': '8 Religious Places'}, {'text': '4 A...
#
#                        SOCIETY_NAME                  BUILDING_NAME  \
# 0                            Evolve                         Evolve
# 1     Annes Fortune Greenhomes Swan  Annes Fortune Greenhomes Swan
# 2                       The Olympus                    The Olympus
# 3                       The Olympus                    The Olympus
# 4               Siva Sai Infra Myra            Siva Sai Infra Myra
# ...                             ...                            ...
# 9482                            NaN                            NaN
# 9483                            NaN                            NaN
# 9484                            NaN                            NaN
# 9485             Greenwoods Project             Greenwoods Project
# 9486                  Pavan Heights                  Pavan Heights
#
#                                                location FLOOR_NUM
# 0     {'CITY': '268', 'CITY_NAME': 'Secunderabad', '...         2
# 1     {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...         1
# 2     {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...         1
# 3     {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...         1
# 4     {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...       NaN
# ...                                                 ...       ...
# 9482  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...       NaN
# 9483  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...       NaN
# 9484  {'CITY': '268', 'CITY_NAME': 'Secunderabad', '...         1
# 9485  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...         4
# 9486  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...         3
#
# [9487 rows x 33 columns]

# %%
drop_cols=["SPID","PROP_ID","DESCRIPTION","FEATURES","REGISTER_DATE","CLASS","PROP_NAME","REGISTER_DATE__U","REGISTERED_DAYS","SOCIETY_NAME","BUILDING_NAME","AMENITIES","ALT_TAG","PRODUCT_TYPE","EXPIRY_DATE","PROP_HEADING","CLASS_HEADING","PRIMARY_TAGS",'TOTAL_LANDMARK_COUNT', 'FORMATTED_LANDMARK_DETAILS','TRANSACT_TYPE','POSTING_DATE','FURNISH', 'FACING','PROJ_ID','BUILDING_ID', 'VERIFIED', 'PROPERTY_TYPE__U', 'SECONDARY_TAGS', 'TOTAL_LANDMARK_COUNT', 'FORMATTED_LANDMARK_DETAILS','SECONDARY_TAGS', 'TOTAL_LANDMARK_COUNT', 'FORMATTED_LANDMARK_DETAILS','SECONDARY_TAGS', 'TOTAL_LANDMARK_COUNT', 'FORMATTED_LANDMARK_DETAILS','SECONDARY_TAGS', 'TOTAL_LANDMARK_COUNT', 'FORMATTED_LANDMARK_DETAILS','SECONDARY_TAGS', 'TOTAL_LANDMARK_COUNT', 'FORMATTED_LANDMARK_DETAILS','SECONDARY_TAGS', 'TOTAL_LANDMARK_COUNT', 'FORMATTED_LANDMARK_DETAILS','SECONDARY_TAGS', 'TOTAL_LANDMARK_COUNT','SECONDARY_TAGS', 'TOTAL_LANDMARK_COUNT','SECONDARY_TAGS','TOTAL_LANDMARK_COUNT','FORMATTED_LANDMARK_DETAILS']
df_train = df_train.drop(columns = drop_cols)

# %%
df_train.columns
# Out:
# Index(['PREFERENCE', 'PROPERTY_TYPE', 'CITY', 'OWNTYPE', 'BEDROOM_NUM',
#        'PRICE_PER_UNIT_AREA', 'AGE', 'TOTAL_FLOOR', 'UPDATE_DATE', 'RES_COM',
#        'PROPERTY_NUMBER', 'MIN_PRICE', 'MAX_PRICE', 'PRICE_SQFT',
#        'MAP_DETAILS', 'MIN_AREA_SQFT', 'MAX_AREA_SQFT', 'TOP_USPS', 'AREA',
#        'SECONDARY_AREA', 'PRICE', 'VALUE_LABEL', 'CLASS_LABEL', 'location',
#        'BALCONY_NUM', 'FLOOR_NUM'],
#       dtype='object')

# %%
df_train
# Out:
#      PREFERENCE              PROPERTY_TYPE          CITY  OWNTYPE  \
# 0             S      Residential Apartment  Secunderabad        1
# 1             S      Residential Apartment     Hyderabad        1
# 2             S      Residential Apartment     Hyderabad        1
# 3             S      Residential Apartment     Hyderabad        1
# 4             S    Independent House/Villa     Hyderabad        1
# ...         ...                        ...           ...      ...
# 9482          S           Residential Land     Hyderabad        1
# 9483          S           Residential Land     Hyderabad        1
# 9484          R  Independent/Builder Floor  Secunderabad        0
# 9485          S      Residential Apartment     Hyderabad        1
# 9486          S      Residential Apartment     Hyderabad        1
#
#       BEDROOM_NUM  PRICE_PER_UNIT_AREA  AGE  TOTAL_FLOOR    UPDATE_DATE  \
# 0             2.0               5700.0    1          5.0  1689100520000
# 1             2.0               6000.0    5         20.0  1681280381000
# 2             4.0                  0.0    5         20.0  1686225628000
# 3             3.0              20049.0    5         20.0  1686225627000
# 4             3.0               8999.0    5          0.0  1689331617000
# ...           ...                  ...  ...          ...            ...
# 9482          NaN              19000.0    0          NaN  1687852504000
# 9483          NaN              11000.0    0          NaN  1687852513000
# 9484          2.0                 15.0    1          3.0  1691679461000
# 9485          3.0               6400.0    5          5.0  1692345025000
# 9486          2.0               5328.0    6          5.0  1691741368000
#
#      RES_COM  PROPERTY_NUMBER  MIN_PRICE  MAX_PRICE  PRICE_SQFT  \
# 0          R                1    6925500    6925500      5700.0
# 1          R                8    6930000    8370000      6000.0
# 2          R                2          0          0         0.0
# 3          R                2   20200000   20200000     20049.0
# 4          R                4   24192000   28728000      8999.0
# ...      ...              ...        ...        ...         ...
# 9482       R                1    3173000    3173000     19000.0
# 9483       R                1    3300000    3300000     11000.0
# 9484       R                1      15000      15000        15.0
# 9485       R                1   10240000   10240000      6400.0
# 9486       R                1    6500500    6500500      5328.0
#
#                                             MAP_DETAILS  MIN_AREA_SQFT  \
# 0     {'LATITUDE': '17.575957', 'LONGITUDE': '78.471...     112.877145
# 1     {'LATITUDE': '17.522103', 'LONGITUDE': '78.384...     107.302965
# 2     {'LATITUDE': '17.41977', 'LONGITUDE': '78.34969'}     267.560640
# 3     {'LATITUDE': '17.41977', 'LONGITUDE': '78.34969'}     186.735030
# 4     {'LATITUDE': '17.513816', 'LONGITUDE': '78.244...     249.723264
# ...                                                 ...            ...
# 9482  {'LATITUDE': '17.4639176', 'LONGITUDE': '78.62...     139.633209
# 9483  {'LATITUDE': '16.985875', 'LONGITUDE': '78.499...     250.838100
# 9484  {'LATITUDE': '17.4653875', 'LONGITUDE': '78.47...      92.903000
# 9485  {'LATITUDE': '17.47078', 'LONGITUDE': '78.30668'}     148.644800
# 9486  {'LATITUDE': '17.4011618', 'LONGITUDE': '78.37...     113.341660
#
#       MAX_AREA_SQFT                                           TOP_USPS  \
# 0        112.877145                                                NaN
# 1        129.599685                                                NaN
# 2        278.709000                                                NaN
# 3        187.664060                                                NaN
# 4        296.546376                                                NaN
# ...             ...                                                ...
# 9482     139.633209  ['East Facing', 'Overlooking Park/Garden', 'Ov...
# 9483     250.838100  ['East Facing', 'Overlooking Park/Garden', 'Ov...
# 9484      92.903000                                                NaN
# 9485     148.644800  ['East Facing', 'The Indian Public School  Nea...
# 9486     113.341660  ['East Facing', 'Pavitra International School ...
#
#                    AREA        SECONDARY_AREA             PRICE VALUE_LABEL  \
# 0           1215 sq.ft.          112.88 sq.m.           69.25 L    Freehold
# 1     1155-1395  sq.ft.    107.3-129.6  sq.m.    69.3  - 83.7 L    Freehold
# 2     2880-3000  sq.ft.  267.56-278.71  sq.m.  Price on Request    Freehold
# 3     2010-2020  sq.ft.  186.74-187.66  sq.m.   2.02  - 2.02 Cr    Freehold
# 4     2688-3192  sq.ft.  249.72-296.55  sq.m.   2.42  - 2.87 Cr    Freehold
# ...                 ...                   ...               ...         ...
# 9482        1503 sq.ft.          139.63 sq.m.           31.73 L    Freehold
# 9483        2700 sq.ft.          250.84 sq.m.              33 L    Freehold
# 9484        1000 sq.ft.            92.9 sq.m.            15,000         NaN
# 9485        1600 sq.ft.          148.64 sq.m.           1.02 Cr    Freehold
# 9486        1220 sq.ft.          113.34 sq.m.              65 L    Freehold
#
#      CLASS_LABEL                                           location  \
# 0         Dealer  {'CITY': '268', 'CITY_NAME': 'Secunderabad', '...
# 1        Builder  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 2        Builder  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 3        Builder  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 4        Builder  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# ...          ...                                                ...
# 9482      Dealer  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 9483      Dealer  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 9484      Dealer  {'CITY': '268', 'CITY_NAME': 'Secunderabad', '...
# 9485      Dealer  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 9486      Dealer  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
#
#       BALCONY_NUM FLOOR_NUM
# 0             1.0         2
# 1             NaN         1
# 2             NaN         1
# 3             NaN         1
# 4             NaN       NaN
# ...           ...       ...
# 9482          NaN       NaN
# 9483          NaN       NaN
# 9484          1.0         1
# 9485          2.0         4
# 9486          2.0         3
#
# [9487 rows x 26 columns]

# %%
#sorting
df = df_train.sort_values(by='PRICE_SQFT', ascending=True)

# %%
check1 = int(len(df) * 0.3)  
check2 = int(len(df) * 0.2)

# %%
#data Split

split1 = df.iloc[:check1]
split2= df.iloc[check1:check1+check2]
split3 = df.iloc[check1+check2:]

len1=len(split1)
len2=len(split2)
len3=len(split3)

# %%
#bus_stop_distance:

random_values = np.random.randint(10,25, size=len1)  
# Assign the random values to the particular column
# split1.reset_index(drop=True, inplace=True)
column_name = 'bus_stop_distance'  
split1[column_name] = random_values

random_values = np.random.randint(5,15, size=len2)  
# Assign the random values to the particular column
split2.reset_index(drop=True)#, inplace=True)
column_name = 'bus_stop_distance'  
split2[column_name] = random_values

random_values = np.random.randint(0,6, size=len3)  
# Assign the random values to the particular column
column_name = 'bus_stop_distance'  
split3[column_name] = random_values

# %%
#railway_distance:

random_values = np.random.randint(80,150, size=len1)  
# Assign the random values to the particular column
# split1.reset_index(drop=True, inplace=True)
column_name = 'railway_distance'  
split1[column_name] = random_values

random_values = np.random.randint(25,85, size=len2)  
# Assign the random values to the particular column
split2.reset_index(drop=True)#, inplace=True)
column_name = 'railway_distance'  
split2[column_name] = random_values

random_values = np.random.randint(10,25, size=len3)  
# Assign the random values to the particular column
column_name = 'railway_distance'  
split3[column_name] = random_values

# %%
#bank_distance

random_values = np.random.randint(10,25, size=len1)  
# Assign the random values to the particular column
# split1.reset_index(drop=True, inplace=True)
column_name = 'bank_distance'  
split1[column_name] = random_values

random_values = np.random.randint(5,10, size=len2)  
# Assign the random values to the particular column
split2.reset_index(drop=True)#, inplace=True)
column_name = 'bank_distance'  
split2[column_name] = random_values

random_values = np.random.randint(0,6, size=len3)  
# Assign the random values to the particular column
column_name = 'bank_distance'  
split3[column_name] = random_values

# %%
#school_distance

random_values = np.random.randint(25,40, size=len1)  
# Assign the random values to the particular column
# split1.reset_index(drop=True, inplace=True)
column_name = 'school_distance'  
split1[column_name] = random_values

random_values = np.random.randint(10,25, size=len2)  
# Assign the random values to the particular column
split2.reset_index(drop=True)#, inplace=True)
column_name = 'school_distance'  
split2[column_name] = random_values

random_values = np.random.randint(0,10, size=len3)  
# Assign the random values to the particular column
column_name = 'school_distance'  
split3[column_name] = random_values

# %%
#hospital_distance

random_values = np.random.randint(25,30, size=len1)  
# Assign the random values to the particular column
# split1.reset_index(drop=True, inplace=True)
column_name = 'hospital_distance'  
split1[column_name] = random_values

random_values = np.random.randint(10,25, size=len2)  
# Assign the random values to the particular column
split2.reset_index(drop=True)#, inplace=True)
column_name = 'hospital_distance'  
split2[column_name] = random_values

random_values = np.random.randint(0,10, size=len3)  
# Assign the random values to the particular column
column_name = 'hospital_distance'  
split3[column_name] = random_values

# %%
#petrol_bunk_distance

random_values = np.random.randint(10,50, size=len1)  
# Assign the random values to the particular column
# split1.reset_index(drop=True, inplace=True)
column_name = 'petrol_bunk_distance'  
split1[column_name] = random_values

random_values = np.random.randint(5,10, size=len2)  
# Assign the random values to the particular column
split2.reset_index(drop=True)#, inplace=True)
column_name = 'petrol_bunk_distance'  
split2[column_name] = random_values

random_values = np.random.randint(0,5, size=len3)  
# Assign the random values to the particular column
column_name = 'petrol_bunk_distance'  
split3[column_name] = random_values

# %%
#parks_distance

random_values = np.random.randint(10,50, size=len1)  
# Assign the random values to the particular column
# split1.reset_index(drop=True, inplace=True)
column_name = 'parks_distance'  
split1[column_name] = random_values

random_values = np.random.randint(5,10, size=len2)  
# Assign the random values to the particular column
split2.reset_index(drop=True)#, inplace=True)
column_name = 'parks_distance'  
split2[column_name] = random_values

random_values = np.random.randint(0,5, size=len3)  
# Assign the random values to the particular column
column_name = 'parks_distance'  
split3[column_name] = random_values

# %%
#hotel_distance

random_values = np.random.randint(10,100, size=len1)  
# Assign the random values to the particular column
# split1.reset_index(drop=True, inplace=True)
column_name = 'hotel_distance'  
split1[column_name] = random_values

random_values = np.random.randint(5,10, size=len2)  
# Assign the random values to the particular column
split2.reset_index(drop=True)#, inplace=True)
column_name = 'hotel_distance'  
split2[column_name] = random_values

random_values = np.random.randint(0,5, size=len3)  
# Assign the random values to the particular column
column_name = 'hotel_distance'  
split3[column_name] = random_values

# %%
#schools_distance

random_values = np.random.randint(10,100, size=len1)  
# Assign the random values to the particular column
# split1.reset_index(drop=True, inplace=True)
column_name = 'schools_distance'  
split1[column_name] = random_values

random_values = np.random.randint(5,10, size=len2)  
# Assign the random values to the particular column
split2.reset_index(drop=True)#, inplace=True)
column_name = 'schools_distance'  
split2[column_name] = random_values

random_values = np.random.randint(0,5, size=len3)  
# Assign the random values to the particular column
column_name = 'schools_distance'  
split3[column_name] = random_values

# %%
#college_distance

random_values = np.random.randint(10,100, size=len1)  
# Assign the random values to the particular column
# split1.reset_index(drop=True, inplace=True)
column_name = 'college_distance'  
split1[column_name] = random_values

random_values = np.random.randint(5,10, size=len2)  
# Assign the random values to the particular column
split2.reset_index(drop=True)#, inplace=True)
column_name = 'college_distance'  
split2[column_name] = random_values

random_values = np.random.randint(0,10, size=len3)  
# Assign the random values to the particular column
column_name = 'college_distance'  
split3[column_name] = random_values

# %%
#highway_distance

random_values = np.random.randint(10,100, size=len1)    
# Assign the random values to the particular column
# split1.reset_index(drop=True, inplace=True)
column_name = 'highway_distance'  
split1[column_name] = random_values

random_values = np.random.randint(5,10, size=len2)  
# Assign the random values to the particular column
split2.reset_index(drop=True)#, inplace=True)
column_name = 'highway_distance'  
split2[column_name] = random_values

random_values = np.random.randint(0,10, size=len3)  
# Assign the random values to the particular column
column_name = 'highway_distance'  
split3[column_name] = random_values

# %%
#police_station_distance

random_values = np.random.randint(80,150, size=len1)  
# Assign the random values to the particular column
# split1.reset_index(drop=True, inplace=True)
column_name = 'police_station_distance'  
split1[column_name] = random_values

random_values = np.random.randint(25,85, size=len2)  
# Assign the random values to the particular column
split2.reset_index(drop=True)#, inplace=True)
column_name = 'police_station_distance'  
split2[column_name] = random_values

random_values = np.random.randint(0,25, size=len3)  
# Assign the random values to the particular column
column_name = 'police_station_distance'  
split3[column_name] = random_values

# %%
#bank_distance

random_values = np.random.randint(80,150, size=len1)  
# Assign the random values to the particular column
# split1.reset_index(drop=True, inplace=True)
column_name = 'bank_distance'  
split1[column_name] = random_values

random_values = np.random.randint(25,85, size=len2)  
# Assign the random values to the particular column
split2.reset_index(drop=True)#, inplace=True)
column_name = 'bank_distance'  
split2[column_name] = random_values

random_values = np.random.randint(0,25, size=len3)  
# Assign the random values to the particular column
column_name = 'bank_distance'  
split3[column_name] = random_values

# %%
#merging

df = pd.concat([split1, split2, split3], axis=0)

df.reset_index(drop=True, inplace=True)

print(df)
# Out:
#      PREFERENCE            PROPERTY_TYPE       CITY  OWNTYPE  BEDROOM_NUM  \
# 0             S    Residential Apartment  Hyderabad        1          2.0
# 1             S         Residential Land  Hyderabad        1          NaN
# 2             S    Residential Apartment  Hyderabad        1          3.0
# 3             S    Residential Apartment  Hyderabad        1          4.0
# 4             S    Residential Apartment  Hyderabad        1          3.0
# ...         ...                      ...        ...      ...          ...
# 9482          S  Independent House/Villa  Hyderabad        1          3.0
# 9483          S         Residential Land  Hyderabad        1          NaN
# 9484          S         Residential Land  Hyderabad        1          NaN
# 9485          S         Residential Land  Hyderabad        1          NaN
# 9486          S         Residential Land  Hyderabad        1          NaN
#
#       PRICE_PER_UNIT_AREA  AGE  TOTAL_FLOOR    UPDATE_DATE RES_COM  \
# 0                     0.0    5         20.0  1690543569000       R
# 1                     0.0    0          0.0  1689335885000       R
# 2                     0.0    5         35.0  1688374368000       R
# 3                     0.0    5         35.0  1688374370000       R
# 4                     0.0    5         20.0  1691363289000       R
# ...                   ...  ...          ...            ...     ...
# 9482          100000000.0    5          3.0  1688458532000       R
# 9483          142857142.0    0         10.0  1690561175000       R
# 9484          160000000.0    0          5.0  1690623533000       R
# 9485          500000000.0    0         30.0  1691137867000       R
# 9486          600000000.0    0          NaN  1690564941000       R
#
#       PROPERTY_NUMBER   MIN_PRICE   MAX_PRICE   PRICE_SQFT  \
# 0                   2           0           0          0.0
# 1                   3           0           0          0.0
# 2                   1           0           0          0.0
# 3                   2           0           0          0.0
# 4                   5           0           0          0.0
# ...               ...         ...         ...          ...
# 9482                1   100000000   100000000  100000000.0
# 9483                1   150000000   150000000  142857142.0
# 9484                1   160000000   160000000  160000000.0
# 9485                1  2147483647  2147483647  500000000.0
# 9486                1  2147483647  2147483647  600000000.0
#
#                                             MAP_DETAILS  MIN_AREA_SQFT  \
# 0     {'LATITUDE': '17.430303', 'LONGITUDE': '78.663...     126.162274
# 1            {'LATITUDE': '17.11', 'LONGITUDE': '78.5'}     167.225400
# 2     {'LATITUDE': '17.409989', 'LONGITUDE': '78.397...     267.189028
# 3     {'LATITUDE': '17.409989', 'LONGITUDE': '78.397...     386.011965
# 4     {'LATITUDE': '17.41977', 'LONGITUDE': '78.34969'}     155.148010
# ...                                                 ...            ...
# 9482  {'LATITUDE': '17.233562897673416', 'LONGITUDE'...    4046.854680
# 9483  {'LATITUDE': '17.492871', 'LONGITUDE': '78.239...    4249.197414
# 9484  {'LATITUDE': '17.443354', 'LONGITUDE': '78.182...    4046.854680
# 9485   {'LATITUDE': '17.40223', 'LONGITUDE': '78.3444'}     499.911043
# 9486   {'LATITUDE': '17.40223', 'LONGITUDE': '78.3444'}   20234.273400
#
#       MAX_AREA_SQFT                                           TOP_USPS  \
# 0        126.719692                                                NaN
# 1        334.450800                                                NaN
# 2        267.189028                                                NaN
# 3        484.582048                                                NaN
# 4        215.534960                                                NaN
# ...             ...                                                ...
# 9482    4046.854680                                                NaN
# 9483    4249.197414                          ['Gaudium School Nearby']
# 9484    4046.854680  ['East Facing', 'Corner Property', 'Overlookin...
# 9485     499.911043                                                NaN
# 9486   20234.273400           ['East Facing', 'Overlooking Main Road']
#
#                    AREA        SECONDARY_AREA             PRICE VALUE_LABEL  \
# 0     1358-1364  sq.ft.  126.16-126.72  sq.m.  Price on Request    Freehold
# 1     1800-3600  sq.ft.  167.23-334.45  sq.m.  Price on Request    Freehold
# 2           2876 sq.ft.          267.19 sq.m.  Price on Request    Freehold
# 3     4155-5216  sq.ft.  386.01-484.58  sq.m.  Price on Request    Freehold
# 4     1670-2320  sq.ft.  155.15-215.53  sq.m.  Price on Request    Freehold
# ...                 ...                   ...               ...         ...
# 9482       43560 sq.ft.         4046.85 sq.m.             10 Cr    Freehold
# 9483       45738 sq.ft.          4249.2 sq.m.             15 Cr    Freehold
# 9484       43560 sq.ft.         4046.85 sq.m.             16 Cr    Freehold
# 9485        5381 sq.ft.          499.91 sq.m.  Price on Request    Freehold
# 9486      217800 sq.ft.        20234.27 sq.m.            300 Cr    Freehold
#
#      CLASS_LABEL                                           location  \
# 0        Builder  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 1         Dealer  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 2        Builder  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 3        Builder  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 4         Dealer  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# ...          ...                                                ...
# 9482      Dealer  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 9483      Dealer  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 9484      Dealer  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 9485      Dealer  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 9486      Dealer  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
#
#       BALCONY_NUM FLOOR_NUM  bus_stop_distance  railway_distance  \
# 0             NaN         1                 23               142
# 1             NaN       NaN                 18               145
# 2             NaN         1                 16               147
# 3             NaN         1                 16               129
# 4             NaN         1                 16               112
# ...           ...       ...                ...               ...
# 9482          2.0       NaN                  3                17
# 9483          NaN       NaN                  5                20
# 9484          NaN       NaN                  4                11
# 9485          NaN       NaN                  4                16
# 9486          NaN       NaN                  4                19
#
#       bank_distance  school_distance  hospital_distance  petrol_bunk_distance  \
# 0               123               35                 25                    35
# 1               146               36                 29                    22
# 2               115               25                 25                    36
# 3               121               27                 27                    46
# 4                97               32                 28                    15
# ...             ...              ...                ...                   ...
# 9482             24                6                  3                     3
# 9483             19                5                  6                     1
# 9484             17                2                  6                     0
# 9485              9                5                  9                     3
# 9486              2                8                  8                     0
#
#       parks_distance  hotel_distance  schools_distance  college_distance  \
# 0                 40              32                73                56
# 1                 36              42                74                23
# 2                 32              20                88                83
# 3                 41              34                72                12
# 4                 45              33                24                22
# ...              ...             ...               ...               ...
# 9482               4               1                 4                 8
# 9483               2               1                 2                 8
# 9484               0               2                 1                 4
# 9485               0               4                 0                 8
# 9486               0               4                 1                 6
#
#       highway_distance  police_station_distance
# 0                   77                      134
# 1                   93                      135
# 2                   30                      108
# 3                   98                       96
# 4                   98                       92
# ...                ...                      ...
# 9482                 9                       10
# 9483                 5                        2
# 9484                 3                       20
# 9485                 7                       16
# 9486                 3                       19
#
# [9487 rows x 38 columns]

# %%
df_train=df

# %% [markdown]
# ### Missing values

# %%
total = df_train.isnull().sum().sort_values(ascending=False)
percent = (df_train.isnull().sum()*100/df_train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                       Total    Percent
# FLOOR_NUM              4468  47.096026
# TOP_USPS               4115  43.375145
# BALCONY_NUM            3293  34.710657
# BEDROOM_NUM            2814  29.661642
# VALUE_LABEL            1560  16.443554
# TOTAL_FLOOR             576   6.071466
# PREFERENCE                0   0.000000
# bank_distance             0   0.000000
# location                  0   0.000000
# bus_stop_distance         0   0.000000
# railway_distance          0   0.000000
# hospital_distance         0   0.000000
# school_distance           0   0.000000
# petrol_bunk_distance      0   0.000000
# parks_distance            0   0.000000
# hotel_distance            0   0.000000
# schools_distance          0   0.000000
# college_distance          0   0.000000
# highway_distance          0   0.000000
# CLASS_LABEL               0   0.000000

# %%
df_train = df_train.drop((missing_data[missing_data['Total'] > 1]).index,axis=1)
df_train.isnull().sum().max()
# Out:
# 0

# %%
df_train.columns.tolist()
# Out:
# ['PREFERENCE',
#  'PROPERTY_TYPE',
#  'CITY',
#  'OWNTYPE',
#  'PRICE_PER_UNIT_AREA',
#  'AGE',
#  'UPDATE_DATE',
#  'RES_COM',
#  'PROPERTY_NUMBER',
#  'MIN_PRICE',
#  'MAX_PRICE',
#  'PRICE_SQFT',
#  'MAP_DETAILS',
#  'MIN_AREA_SQFT',
#  'MAX_AREA_SQFT',
#  'AREA',
#  'SECONDARY_AREA',
#  'PRICE',
#  'CLASS_LABEL',
#  'location',
#  'bus_stop_distance',
#  'railway_distance',
#  'bank_distance',
#  'school_distance',
#  'hospital_distance',
#  'petrol_bunk_distance',
#  'parks_distance',
#  'hotel_distance',
#  'schools_distance',
#  'college_distance',
#  'highway_distance',
#  'police_station_distance']

# %%
X_num = df_train.select_dtypes(exclude='object')
X_cat = df_train.select_dtypes(include='object')

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
encoded_labels = X_cat.apply(label_encoder.fit_transform)
X_cat=encoded_labels
print(X_cat.dtypes)
print(encoded_labels.columns)
print(X_num.dtypes)
# Out:
# PREFERENCE        int64
# PROPERTY_TYPE     int64
# CITY              int64
# RES_COM           int64
# MAP_DETAILS       int64
# AREA              int64
# SECONDARY_AREA    int64
# PRICE             int64
# CLASS_LABEL       int64
# location          int64
# dtype: object
# Index(['PREFERENCE', 'PROPERTY_TYPE', 'CITY', 'RES_COM', 'MAP_DETAILS', 'AREA',
#        'SECONDARY_AREA', 'PRICE', 'CLASS_LABEL', 'location'],
#       dtype='object')
# OWNTYPE                      int64
# PRICE_PER_UNIT_AREA        float64
# AGE                          int64
# UPDATE_DATE                  int64
# PROPERTY_NUMBER              int64
# MIN_PRICE                    int64
# MAX_PRICE                    int64
# PRICE_SQFT                 float64
# MIN_AREA_SQFT              float64
# MAX_AREA_SQFT              float64
# bus_stop_distance            int64
# railway_distance             int64
# bank_distance                int64
# school_distance              int64
# hospital_distance            int64
# petrol_bunk_distance         int64
# parks_distance               int64
# hotel_distance               int64
# schools_distance             int64
# college_distance             int64
# highway_distance             int64
# police_station_distance      int64
# dtype: object

# %%
X_cat.head(10)
# Out:
#    PREFERENCE  PROPERTY_TYPE  CITY  RES_COM  MAP_DETAILS  AREA  \
# 0           2              4     0        0          802   357
# 1           2              5     0        0           45   796
# 2           2              4     0        0          591  1247
# 3           2              4     0        0          591  1522
# 4           2              4     0        0          710   699
# 5           2              4     0        0         1832   257
# 6           2              4     0        0         1833   615
# 7           2              4     0        0         1833    77
# 8           2              4     0        0         1608   617
# 9           2              5     0        0           26   518
#
#    SECONDARY_AREA  PRICE  CLASS_LABEL  location
# 0             308   2378            0      3465
# 1             745   2378            1      3420
# 2            1198   2378            0      4362
# 3            1471   2378            0      4362
# 4             652   2378            1      3428
# 5             207   2378            1      3495
# 6             567   2378            0      3588
# 7              28   2378            0      3588
# 8             569   2378            1      3587
# 9             468   2378            1      3572

# %%
df_train = X_num.join(X_cat)

# %%
df_train.head(10)
# Out:
#    OWNTYPE  PRICE_PER_UNIT_AREA  AGE    UPDATE_DATE  PROPERTY_NUMBER  \
# 0        1                  0.0    5  1690543569000                2
# 1        1                  0.0    0  1689335885000                3
# 2        1                  0.0    5  1688374368000                1
# 3        1                  0.0    5  1688374370000                2
# 4        1                  0.0    5  1691363289000                5
# 5        1                  0.0    5  1689620229000                1
# 6        1                  0.0    5  1692349487000               10
# 7        1                  0.0    5  1692349485000                2
# 8        1                  0.0    5  1689342465000                8
# 9        1                  0.0    0  1689338739000                2
#
#    MIN_PRICE  MAX_PRICE  PRICE_SQFT  MIN_AREA_SQFT  MAX_AREA_SQFT  \
# 0          0          0         0.0     126.162274     126.719692
# 1          0          0         0.0     167.225400     334.450800
# 2          0          0         0.0     267.189028     267.189028
# 3          0          0         0.0     386.011965     484.582048
# 4          0          0         0.0     155.148010     215.534960
# 5          0          0         0.0     119.380355     119.380355
# 6          0          0         0.0     147.622867     177.073118
# 7          0          0         0.0     102.379106     119.566161
# 8          0          0         0.0     147.715770     191.380180
# 9          0          0         0.0     139.354500    3350.082180
#
#    bus_stop_distance  railway_distance  bank_distance  school_distance  \
# 0                 23               142            123               35
# 1                 18               145            146               36
# 2                 16               147            115               25
# 3                 16               129            121               27
# 4                 16               112             97               32
# 5                 11                99            139               38
# 6                 19               145            116               27
# 7                 19                89             81               36
# 8                 17               105            119               39
# 9                 22                98            117               29
#
#    hospital_distance  petrol_bunk_distance  parks_distance  hotel_distance  \
# 0                 25                    35              40              32
# 1                 29                    22              36              42
# 2                 25                    36              32              20
# 3                 27                    46              41              34
# 4                 28                    15              45              33
# 5                 27                    26              39              57
# 6                 26                    16              45              92
# 7                 25                    42              31              75
# 8                 28                    39              49              67
# 9                 27                    36              11              77
#
#    schools_distance  college_distance  highway_distance  \
# 0                73                56                77
# 1                74                23                93
# 2                88                83                30
# 3                72                12                98
# 4                24                22                98
# 5                42                17                75
# 6                86                67                76
# 7                99                67                61
# 8                74                17                43
# 9                68                46                34
#
#    police_station_distance  PREFERENCE  PROPERTY_TYPE  CITY  RES_COM  \
# 0                      134           2              4     0        0
# 1                      135           2              5     0        0
# 2                      108           2              4     0        0
# 3                       96           2              4     0        0
# 4                       92           2              4     0        0
# 5                      108           2              4     0        0
# 6                      124           2              4     0        0
# 7                       95           2              4     0        0
# 8                      101           2              4     0        0
# 9                      115           2              5     0        0
#
#    MAP_DETAILS  AREA  SECONDARY_AREA  PRICE  CLASS_LABEL  location
# 0          802   357             308   2378            0      3465
# 1           45   796             745   2378            1      3420
# 2          591  1247            1198   2378            0      4362
# 3          591  1522            1471   2378            0      4362
# 4          710   699             652   2378            1      3428
# 5         1832   257             207   2378            1      3495
# 6         1833   615             567   2378            0      3588
# 7         1833    77              28   2378            0      3588
# 8         1608   617             569   2378            1      3587
# 9           26   518             468   2378            1      3572

# %% [markdown]
# # Modeling

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = df_train.drop(['PRICE'],axis=1)
y = df_train['PRICE']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=7)

# %%
param_grid =   {
    'n_estimators' : [1000, 10000],  
    'boosting_type': ['gbdt'],
    'num_leaves': [30, 35],
    #'learning_rate': [0.01, 0.02, 0.05],
    #'colsample_bytree': [0.8, 0.95 ],
    'subsample': [0.8, 0.95],
    'is_unbalance': [True, False],
    #'reg_alpha'  : [0.01, 0.02, 0.05],
    #'reg_lambda' : [0.01, 0.02, 0.05],
    'min_split_gain' :[0.01, 0.02, 0.05]
    }

# %%
from xgboost import XGBRegressor
model = XGBRegressor(learning_rate=0.09,n_estimators = 200,min_child_weight = 1, subsample = 0.9, max_depth=10, colsample_bytree
= 0.8,reg_lambda = 0, reg_alpha = 0, gamma = 0.2,objective="reg:squarederror", eval_metric="rmse")
# , early_stopping_rounds=10

# %%
model.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              gamma=0.2, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.09, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=200, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)
print(f"Mean Absolute Error: {mean_absolute_error(y_test,y_pred)}")
print(f"Mean Squared Error: {mean_squared_error(y_test,y_pred)}")
print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test,y_pred))}")
print(f"R2 Score: {r2_score(y_test,y_pred)}")
# Out:
# Mean Absolute Error: 22.098289385588735
# Mean Squared Error: 11112.533036331775
# Root Mean Squared Error: 105.41599990671139
# R2 Score: 0.977649205538548

# %%
import pickle

with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
df_train.head(10)
# Out:
#    OWNTYPE  PRICE_PER_UNIT_AREA  AGE    UPDATE_DATE  PROPERTY_NUMBER  \
# 0        1                  0.0    5  1690543569000                2
# 1        1                  0.0    0  1689335885000                3
# 2        1                  0.0    5  1688374368000                1
# 3        1                  0.0    5  1688374370000                2
# 4        1                  0.0    5  1691363289000                5
# 5        1                  0.0    5  1689620229000                1
# 6        1                  0.0    5  1692349487000               10
# 7        1                  0.0    5  1692349485000                2
# 8        1                  0.0    5  1689342465000                8
# 9        1                  0.0    0  1689338739000                2
#
#    MIN_PRICE  MAX_PRICE  PRICE_SQFT  MIN_AREA_SQFT  MAX_AREA_SQFT  \
# 0          0          0         0.0     126.162274     126.719692
# 1          0          0         0.0     167.225400     334.450800
# 2          0          0         0.0     267.189028     267.189028
# 3          0          0         0.0     386.011965     484.582048
# 4          0          0         0.0     155.148010     215.534960
# 5          0          0         0.0     119.380355     119.380355
# 6          0          0         0.0     147.622867     177.073118
# 7          0          0         0.0     102.379106     119.566161
# 8          0          0         0.0     147.715770     191.380180
# 9          0          0         0.0     139.354500    3350.082180
#
#    bus_stop_distance  railway_distance  bank_distance  school_distance  \
# 0                 23               142            123               35
# 1                 18               145            146               36
# 2                 16               147            115               25
# 3                 16               129            121               27
# 4                 16               112             97               32
# 5                 11                99            139               38
# 6                 19               145            116               27
# 7                 19                89             81               36
# 8                 17               105            119               39
# 9                 22                98            117               29
#
#    hospital_distance  petrol_bunk_distance  parks_distance  hotel_distance  \
# 0                 25                    35              40              32
# 1                 29                    22              36              42
# 2                 25                    36              32              20
# 3                 27                    46              41              34
# 4                 28                    15              45              33
# 5                 27                    26              39              57
# 6                 26                    16              45              92
# 7                 25                    42              31              75
# 8                 28                    39              49              67
# 9                 27                    36              11              77
#
#    schools_distance  college_distance  highway_distance  \
# 0                73                56                77
# 1                74                23                93
# 2                88                83                30
# 3                72                12                98
# 4                24                22                98
# 5                42                17                75
# 6                86                67                76
# 7                99                67                61
# 8                74                17                43
# 9                68                46                34
#
#    police_station_distance  PREFERENCE  PROPERTY_TYPE  CITY  RES_COM  \
# 0                      134           2              4     0        0
# 1                      135           2              5     0        0
# 2                      108           2              4     0        0
# 3                       96           2              4     0        0
# 4                       92           2              4     0        0
# 5                      108           2              4     0        0
# 6                      124           2              4     0        0
# 7                       95           2              4     0        0
# 8                      101           2              4     0        0
# 9                      115           2              5     0        0
#
#    MAP_DETAILS  AREA  SECONDARY_AREA  PRICE  CLASS_LABEL  location
# 0          802   357             308   2378            0      3465
# 1           45   796             745   2378            1      3420
# 2          591  1247            1198   2378            0      4362
# 3          591  1522            1471   2378            0      4362
# 4          710   699             652   2378            1      3428
# 5         1832   257             207   2378            1      3495
# 6         1833   615             567   2378            0      3588
# 7         1833    77              28   2378            0      3588
# 8         1608   617             569   2378            1      3587
# 9           26   518             468   2378            1      3572

# %%
# Load the model from the .pkl file
with open('model.pkl', 'rb') as f:
    model1 = pickle.load(f)

# Define your input data
input_data = pd.DataFrame({"OWNTYPE":[1],
                           "PRICE_PER_UNIT_AREA":[0.0],
                           "AGE":[3],
                           "UPDATE_DATE":[1690543569000],
                           "PROPERTY_NUMBER":[7],
                           "MIN_PRICE":[0],
                           "MAX_PRICE":[0],
                           "PRICE_SQFT":[234],
                           "MIN_AREA_SQFT":[119.380355],
                           "MAX_AREA_SQFT":[119.380355],
                           "bus_stop_distance":[5],
                           "railway_distance":[20],
                           "bank_distance":[3],
                           "school_distance":[2],
                           "hospital_distance":[3],
                           "petrol_bunk_distance":[1],
                           "parks_distance":[6],
                           "hotel_distance":[4],
                           "schools_distance":[2],
                           "college_distance":[0],
                           "highway_distance":[7],
                           "police_station_distance":[10],
                           "PREFERENCE":[2],
                           "PROPERTY_TYPE":[4],
                           "CITY":[0],
                           "RES_COM":[0],
                           "MAP_DETAILS":[345],
                           "AREA":[123],
                           "SECONDARY_AREA":[134],
                           
                           "CLASS_LABEL":[0],
                           "location":[3572]})

# Preprocess the input data if necessary
# processed_input = preprocess(input_data)

# Make predictions using the loaded model
predictions = model.predict(input_data)

# Optionally, post-process the predictions if necessary
# post_processed_predictions = postprocess(predictions)

# Use the predictions or perform other tasks with them

# %%
predictions
# Out:
# array([2271.3564], dtype=float32)
